# %% [markdown]
# <a href="https://colab.research.google.com/github/mbuitragoc/AlgorithmsUN2024I/blob/main/LabML/ML_Max_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Learning to sort with a Neural Network (MLPRegressor)

# %%
import random as rnd
import numpy as np

n=10
Nexamples=1000

X =[]
y =[]
for j in range(Nexamples):
    listA = list(range(n))
    rnd.shuffle(listA)
    X.append(np.array(listA))
    maxim = max(listA)
    y.append(np.array(maxim))

# %%
import pandas as pd
data = pd.DataFrame({'X': [a for a in X], 'y':[a for a in y]})
data
# Out:
#                                   X  y
# 0    [9, 3, 7, 2, 1, 5, 6, 4, 8, 0]  9
# 1    [1, 2, 0, 5, 7, 3, 8, 9, 4, 6]  9
# 2    [7, 0, 9, 3, 5, 8, 2, 6, 1, 4]  9
# 3    [1, 9, 0, 5, 8, 2, 3, 7, 6, 4]  9
# 4    [6, 4, 7, 0, 8, 1, 9, 2, 5, 3]  9
# ..                              ... ..
# 995  [5, 3, 6, 1, 7, 9, 8, 2, 0, 4]  9
# 996  [1, 2, 0, 5, 4, 6, 8, 7, 3, 9]  9
# 997  [6, 3, 7, 4, 2, 8, 5, 9, 0, 1]  9
# 998  [3, 5, 9, 8, 0, 6, 7, 2, 4, 1]  9
# 999  [5, 9, 2, 6, 1, 4, 7, 0, 3, 8]  9
#
# [1000 rows x 2 columns]

# %%
from sklearn.neural_network import MLPRegressor
model = MLPRegressor(hidden_layer_sizes=(100,50,20),random_state=1, max_iter=1000, activation='logistic').fit(X,y)
y_pred =model.predict(X)

import matplotlib.pyplot as plt
plt.plot(model.loss_curve_)
plt.show()

# %%
import pandas as pd
y_p = pd.DataFrame({'y_pred': [round(pred,3) for pred in y_pred]})
y_p
# Out:
#      y_pred
# 0      8.96
# 1      8.96
# 2      8.96
# 3      8.96
# 4      8.96
# ..      ...
# 995    8.96
# 996    8.96
# 997    8.96
# 998    8.96
# 999    8.96
#
# [1000 rows x 1 columns]

# %%
import random as rnd
import numpy as np

n=10
Nexamples=10000

X =[]
y =[]
for j in range(Nexamples):
    listA = list(range(n))
    rnd.shuffle(listA)
    X.append(np.array(listA))
    maxim = max(listA)
    y.append(np.array(maxim))


y_pred = model.predict(X)

import pandas as pd
data = pd.DataFrame({'X': [a for a in X], 'y':[a for a in y], 'y_pred':[ int(round(pred)) for pred in y_pred]})
data
# Out:
#                                    X  y  y_pred
# 0     [9, 6, 0, 4, 2, 1, 7, 5, 8, 3]  9       9
# 1     [8, 3, 4, 9, 0, 6, 2, 7, 1, 5]  9       9
# 2     [4, 6, 5, 7, 0, 9, 1, 3, 2, 8]  9       9
# 3     [2, 9, 8, 1, 0, 4, 7, 3, 6, 5]  9       9
# 4     [3, 0, 8, 2, 5, 1, 4, 7, 6, 9]  9       9
# ...                              ... ..     ...
# 9995  [0, 3, 5, 9, 2, 6, 1, 4, 8, 7]  9       9
# 9996  [9, 5, 3, 4, 6, 7, 8, 1, 0, 2]  9       9
# 9997  [2, 9, 0, 6, 4, 7, 5, 3, 8, 1]  9       9
# 9998  [3, 8, 0, 9, 4, 6, 7, 2, 5, 1]  9       9
# 9999  [9, 3, 6, 1, 7, 4, 2, 5, 0, 8]  9       9
#
# [10000 rows x 3 columns]

# %%
import random as rnd
import numpy as np

n=10
Nexamples=10000

X =[]
y =[]
for j in range(Nexamples):
    listA = list(2*np.array(range(n)))
    rnd.shuffle(listA)
    X.append(np.array(listA))
    maxim = max(listA)
    y.append(np.array(maxim))


y_pred = model.predict(X)

import pandas as pd
data = pd.DataFrame({'X': [a for a in X], 'y':[a for a in y], 'y_pred': [int(round(pred)) for pred in y_pred]})
data
# Out:
#                                         X   y  y_pred
# 0     [14, 4, 0, 8, 18, 10, 2, 12, 16, 6]  18       9
# 1     [18, 10, 12, 4, 14, 2, 8, 0, 6, 16]  18       9
# 2     [12, 8, 0, 10, 16, 18, 4, 2, 14, 6]  18       9
# 3     [6, 2, 12, 8, 18, 10, 4, 14, 0, 16]  18       9
# 4     [16, 2, 14, 4, 18, 8, 6, 12, 0, 10]  18       9
# ...                                   ...  ..     ...
# 9995  [4, 12, 10, 2, 16, 6, 18, 0, 8, 14]  18       9
# 9996  [10, 6, 18, 12, 16, 0, 8, 14, 4, 2]  18       9
# 9997  [16, 10, 8, 0, 4, 18, 14, 2, 12, 6]  18       9
# 9998  [10, 8, 16, 14, 18, 6, 2, 0, 12, 4]  18       9
# 9999  [12, 18, 8, 4, 14, 10, 2, 6, 16, 0]  18       9
#
# [10000 rows x 3 columns]

# %%
import random as rnd
import numpy as np
from sklearn.neural_network import MLPRegressor
import matplotlib.pyplot as plt
import pandas as pd

n=10
Nexamples=1000

X =[]
y =[]

for j in range(Nexamples):
    listA = list(range(n))
    rnd.shuffle(listA)
    X.append(np.array(listA))
    maxim = max(listA)
    y.append(np.array(maxim))

for j in range(Nexamples):
    listA = list(2*np.array(range(n)))
    rnd.shuffle(listA)
    X.append(np.array(listA))
    maxim = max(listA)
    y.append(np.array(maxim))

model = MLPRegressor(hidden_layer_sizes=(100,50,20), max_iter=1000, activation='tanh').fit(X,y)
y_pred =model.predict(X)


plt.plot(model.loss_curve_)
plt.show()

print('Accuracy testing : {:.3f}'.format(model.score(X,y)))

data = pd.DataFrame({'X': [a for a in X], 'y':[a for a in y], 'y_pred': [int(round(pred)) for pred in y_pred]})
data
# Out:
# Accuracy testing : 1.000
#                                         X   y  y_pred
# 0          [1, 4, 7, 6, 2, 3, 9, 5, 8, 0]   9       9
# 1          [6, 0, 8, 5, 1, 3, 9, 2, 7, 4]   9       9
# 2          [2, 9, 7, 3, 8, 4, 5, 0, 1, 6]   9       9
# 3          [1, 2, 6, 9, 5, 4, 7, 0, 3, 8]   9       9
# 4          [2, 9, 0, 6, 7, 8, 1, 3, 5, 4]   9       9
# ...                                   ...  ..     ...
# 1995  [0, 12, 16, 10, 8, 18, 14, 4, 2, 6]  18      18
# 1996  [16, 14, 18, 10, 2, 12, 0, 8, 6, 4]  18      18
# 1997  [6, 16, 4, 0, 14, 18, 8, 2, 12, 10]  18      18
# 1998  [12, 10, 4, 8, 6, 14, 18, 2, 16, 0]  18      18
# 1999  [10, 18, 0, 6, 8, 2, 16, 4, 12, 14]  18      18
#
# [2000 rows x 3 columns]

# %%
import random as rnd
import numpy as np
from sklearn.neural_network import MLPRegressor
import matplotlib.pyplot as plt
import pandas as pd

n=10
Nexamples=1000

X =[]
y =[]

for j in range(Nexamples):
    listA = list(range(n))
    rnd.shuffle(listA)
    X.append(np.array(listA))
    maxim = max(listA)
    y.append(np.array(maxim))

for j in range(Nexamples):
    listA = list(2*np.array(range(n)))
    rnd.shuffle(listA)
    X.append(np.array(listA))
    maxim = max(listA)
    y.append(np.array(maxim))

model = MLPRegressor(hidden_layer_sizes=(100,50,20), max_iter=1000, activation='relu').fit(X,y)
y_pred =model.predict(X)


plt.plot(model.loss_curve_)
plt.show()

print('Accuracy testing : {:.3f}'.format(model.score(X,y)))

data = pd.DataFrame({'X': [a for a in X], 'y':[a for a in y], 'y_pred': [int(round(pred)) for pred in y_pred]})
data
# Out:
# Accuracy testing : 1.000
#                                         X   y  y_pred
# 0          [0, 2, 1, 4, 8, 7, 6, 3, 5, 9]   9       9
# 1          [1, 2, 6, 0, 5, 7, 4, 3, 9, 8]   9       9
# 2          [8, 6, 0, 3, 1, 5, 2, 9, 4, 7]   9       9
# 3          [6, 1, 3, 8, 7, 0, 5, 2, 9, 4]   9       9
# 4          [2, 0, 4, 7, 1, 8, 5, 3, 9, 6]   9       9
# ...                                   ...  ..     ...
# 1995  [12, 0, 18, 4, 10, 8, 16, 2, 14, 6]  18      18
# 1996  [18, 16, 4, 12, 6, 0, 14, 2, 8, 10]  18      18
# 1997  [18, 14, 10, 4, 16, 12, 6, 8, 2, 0]  18      18
# 1998  [12, 18, 6, 8, 4, 10, 16, 14, 0, 2]  18      18
# 1999  [14, 4, 6, 12, 18, 8, 10, 16, 2, 0]  18      18
#
# [2000 rows x 3 columns]

# %%
import random as rnd
import numpy as np
from sklearn.neural_network import MLPRegressor
import matplotlib.pyplot as plt
import pandas as pd

n=10
Nexamples=10000

X =[]
y =[]

for j in range(Nexamples):
    listA = list(range(n))
    rnd.shuffle(listA)
    X.append(np.array(listA))
    maxim = max(listA)
    y.append(np.array(maxim))

for j in range(Nexamples):
    listA = list(2*np.array(range(n)))
    rnd.shuffle(listA)
    X.append(np.array(listA))
    maxim = max(listA)
    y.append(np.array(maxim))

y_pred =model.predict(X)

print('Accuracy testing : {:.3f}'.format(model.score(X,y)))

data = pd.DataFrame({'X': [a for a in X], 'y':[a for a in y], 'y_pred': [int(round(pred)) for pred in y_pred]})
data
# Out:
# Accuracy testing : 0.999
#                                          X   y  y_pred
# 0           [4, 6, 0, 2, 1, 8, 7, 3, 5, 9]   9       9
# 1           [2, 3, 7, 1, 0, 4, 8, 5, 6, 9]   9       9
# 2           [1, 7, 2, 8, 9, 5, 3, 6, 0, 4]   9       9
# 3           [6, 9, 5, 0, 3, 1, 4, 2, 7, 8]   9       9
# 4           [2, 0, 5, 1, 8, 9, 6, 3, 7, 4]   9       9
# ...                                    ...  ..     ...
# 19995  [6, 2, 18, 16, 14, 0, 10, 8, 4, 12]  18      18
# 19996  [16, 12, 6, 14, 2, 0, 8, 18, 4, 10]  18      18
# 19997  [6, 8, 2, 14, 18, 12, 0, 16, 10, 4]  18      18
# 19998  [2, 10, 8, 16, 14, 18, 12, 0, 4, 6]  18      18
# 19999  [18, 0, 6, 4, 16, 14, 8, 12, 2, 10]  18      18
#
# [20000 rows x 3 columns]

# %% [markdown]
# # Learning to find the max value with a Classification and Regression Tree (CART)
#
# * https://towardsdatascience.com/cart-classification-and-regression-trees-for-clean-but-powerful-models-cc89e60b7a85
#
# * https://spotle.ai/feeddetails/Classification-and-Regression-Tree-CART-with-Python/3644
#
# ### Visualize a Decision Tree in 4 Ways with Scikit-Learn and Python
#
# * https://towardsdatascience.com/cart-classification-and-regression-trees-for-clean-but-powerful-models-cc89e60b7a85

# %%
from sklearn.tree import DecisionTreeRegressor
import numpy as np
import matplotlib.pyplot as plt
import random as rnd

n=10
Nexamples=1000

X =[]
y =[]

names = ["x"+str(i) for i in range(n)]

for j in range(Nexamples):
    listA = list(range(n))
    rnd.shuffle(listA)
    X.append(np.array(listA))
    maxim = max(listA)
    y.append(np.array(maxim))

model = DecisionTreeRegressor(max_leaf_nodes = 15).fit(X,y)

# %%
import random as rnd
import numpy as np

n=10
Nexamples=10000

X =[]
y =[]
for j in range(Nexamples):
    listA = list(range(n))
    rnd.shuffle(listA)
    X.append(np.array(listA))
    maxim = max(listA)
    y.append(np.array(maxim))



y_pred = model.predict(X)

import pandas as pd
data = pd.DataFrame({'X': [a for a in X], 'y':[a for a in y], 'y_pred':[int(round(pred)) for pred in y_pred]})
data
# Out:
#                                    X  y  y_pred
# 0     [8, 1, 2, 4, 6, 3, 9, 7, 5, 0]  9       9
# 1     [2, 5, 9, 7, 8, 4, 3, 6, 0, 1]  9       9
# 2     [5, 0, 9, 7, 8, 2, 3, 4, 6, 1]  9       9
# 3     [7, 2, 1, 8, 5, 4, 3, 9, 0, 6]  9       9
# 4     [7, 8, 9, 3, 5, 4, 2, 6, 0, 1]  9       9
# ...                              ... ..     ...
# 9995  [3, 0, 9, 8, 5, 7, 2, 6, 1, 4]  9       9
# 9996  [2, 3, 7, 5, 9, 4, 0, 8, 6, 1]  9       9
# 9997  [3, 5, 2, 6, 7, 0, 8, 9, 1, 4]  9       9
# 9998  [5, 8, 9, 7, 1, 2, 6, 3, 0, 4]  9       9
# 9999  [0, 8, 1, 7, 9, 3, 5, 4, 2, 6]  9       9
#
# [10000 rows x 3 columns]

# %%
from sklearn import tree

text_representation = tree.export_text(model)
print(text_representation)
# Out:
# |--- value: [9.00]

# %%
from sklearn.tree import DecisionTreeRegressor
import numpy as np
import matplotlib.pyplot as plt
import random as rnd

n=10
Nexamples=1000

X =[]
y =[]

names = ["x"+str(i) for i in range(n)]

for j in range(Nexamples):
    listA = list(range(n))
    rnd.shuffle(listA)
    X.append(np.array(listA))
    maxim = max(listA)
    y.append(np.array(maxim))

for j in range(Nexamples):
    listA = list(2*np.array(range(n)))
    rnd.shuffle(listA)
    X.append(np.array(listA))
    maxim = max(listA)
    y.append(np.array(maxim))

model = DecisionTreeRegressor(max_leaf_nodes = 50).fit(X,y)

# %%
import random as rnd
import numpy as np
from sklearn.neural_network import MLPRegressor
import matplotlib.pyplot as plt
import pandas as pd

n=10
Nexamples=10000

X =[]
y =[]

for j in range(Nexamples):
    listA = list(range(n))
    rnd.shuffle(listA)
    X.append(np.array(listA))
    maxim = max(listA)
    y.append(np.array(maxim))

for j in range(Nexamples):
    listA = list(2*np.array(range(n)))
    rnd.shuffle(listA)
    X.append(np.array(listA))
    maxim = max(listA)
    y.append(np.array(maxim))

y_pred =model.predict(X)

print('Accuracy testing : {:.3f}'.format(model.score(X,y)))

data = pd.DataFrame({'X': [a for a in X], 'y':[a for a in y], 'y_pred':[int(round(pred)) for pred in y_pred]})
data
# Out:
# Accuracy testing : 0.990
#                                          X   y  y_pred
# 0           [8, 9, 3, 5, 2, 4, 7, 0, 1, 6]   9       9
# 1           [2, 9, 1, 0, 8, 4, 7, 6, 3, 5]   9       9
# 2           [8, 6, 4, 7, 5, 1, 9, 3, 0, 2]   9       9
# 3           [1, 0, 9, 4, 8, 7, 5, 6, 3, 2]   9       9
# 4           [5, 9, 2, 0, 4, 8, 3, 7, 6, 1]   9       9
# ...                                    ...  ..     ...
# 19995  [4, 6, 14, 16, 0, 8, 18, 10, 2, 12]  18      18
# 19996  [2, 4, 18, 8, 0, 6, 12, 10, 14, 16]  18      18
# 19997  [8, 2, 18, 14, 12, 0, 6, 4, 10, 16]  18      18
# 19998  [16, 6, 12, 14, 10, 2, 18, 0, 4, 8]  18      18
# 19999  [4, 2, 0, 18, 10, 16, 14, 12, 8, 6]  18      18
#
# [20000 rows x 3 columns]

# %%
from sklearn import tree

text_representation = tree.export_text(model)
print(text_representation)
# Out:
# |--- feature_5 <= 9.50
# |   |--- feature_9 <= 9.50
# |   |   |--- feature_3 <= 9.50
# |   |   |   |--- feature_7 <= 9.50
# |   |   |   |   |--- feature_2 <= 9.50
# |   |   |   |   |   |--- value: [9.00]
# |   |   |   |   |--- feature_2 >  9.50
# |   |   |   |   |   |--- value: [18.00]
# |   |   |   |--- feature_7 >  9.50
# |   |   |   |   |--- value: [18.00]
# |   |   |--- feature_3 >  9.50
# |   |   |   |--- value: [18.00]
# |   |--- feature_9 >  9.50
# |   |   |--- value: [18.00]
# |--- feature_5 >  9.50
# |   |--- value: [18.00]

# %%
import graphviz # for plotting decision tree graphs
from sklearn import tree

dot_data = tree.export_graphviz(model, out_file=None,
                                feature_names=names,
                                filled=True,
                                rotate=True,
                               )

graph = graphviz.Source(dot_data)

graph

# %%
from IPython.display import Image
from sklearn import tree
import matplotlib.image as mpimg
import pydotplus
import io
import matplotlib.pyplot as plt

import sys
str1 = "/usr/local/Cellar/graphviz/2.40.1_1/bin/"
sys.path.append(str1)

dot_data = io.StringIO()
tree.export_graphviz(model, out_file=dot_data, filled=True, feature_names = names )

# Draw graph
pydotplus.graph_from_dot_data(dot_data.getvalue()).write_png('dt.png')

plt.figure(figsize=(20, 20))
img = mpimg.imread('dt.png')
imgplot = plt.imshow(img)

plt.show()

# %% [markdown]
# # Random Data

# %%
from sklearn.tree import DecisionTreeRegressor
import numpy as np
import matplotlib.pyplot as plt
import random as rnd

n=10
Nexamples=1000

X =[]
y =[]

names = ["x"+str(i) for i in range(n)]

for j in range(Nexamples):
    listA = rnd.sample(range(1,501), n)
    X.append(np.array(listA))
    maxim = max(listA)
    y.append(np.array(maxim))

for j in range(Nexamples):
    listA = rnd.sample(range(2,1001), n)
    X.append(np.array(listA))
    maxim = max(listA)
    y.append(np.array(maxim))

model = DecisionTreeRegressor(max_leaf_nodes = 50).fit(X,y)

# %%
import random as rnd
import numpy as np
from sklearn.neural_network import MLPRegressor
import matplotlib.pyplot as plt
import pandas as pd

n=10
Nexamples=10000

X =[]
y =[]

for j in range(Nexamples):
    listA = rnd.sample(range(1, 501), n)
    X.append(np.array(listA))
    maxim = max(listA)
    y.append(np.array(maxim))

for j in range(Nexamples):
    listA = rnd.sample(range(2, 1001), n)
    X.append(np.array(listA))
    maxim = max(listA)
    y.append(np.array(maxim))

y_pred =model.predict(X)

print('Accuracy testing : {:.3f}'.format(model.score(X,y)))

data = pd.DataFrame({'X': [a for a in X], 'y':[a for a in y], 'y_pred':[int(round(pred)) for pred in y_pred]})
data
# Out:
# Accuracy testing : 0.932
#                                                        X    y  y_pred
# 0        [24, 373, 73, 212, 486, 201, 108, 357, 232, 74]  486     472
# 1       [147, 185, 94, 257, 188, 444, 32, 437, 112, 122]  444     468
# 2         [75, 322, 388, 76, 40, 233, 232, 142, 54, 296]  388     375
# 3       [121, 133, 440, 319, 257, 379, 30, 349, 40, 406]  440     464
# 4         [427, 253, 43, 7, 288, 375, 482, 293, 148, 37]  482     449
# ...                                                  ...  ...     ...
# 19995  [760, 475, 357, 959, 547, 822, 394, 892, 113, ...  959     926
# 19996  [343, 434, 861, 416, 795, 160, 646, 509, 687, ...  861     810
# 19997  [897, 323, 191, 685, 663, 641, 558, 494, 854, ...  897     954
# 19998  [470, 759, 277, 534, 701, 108, 677, 500, 607, ...  759     926
# 19999   [732, 929, 120, 417, 441, 20, 78, 604, 962, 571]  962     963
#
# [20000 rows x 3 columns]

# %%
from sklearn import tree

text_representation = tree.export_text(model)
print(text_representation)
# Out:
# |--- feature_6 <= 500.50
# |   |--- feature_1 <= 504.50
# |   |   |--- feature_2 <= 503.00
# |   |   |   |--- feature_5 <= 501.00
# |   |   |   |   |--- feature_7 <= 526.50
# |   |   |   |   |   |--- feature_3 <= 502.00
# |   |   |   |   |   |   |--- feature_9 <= 556.00
# |   |   |   |   |   |   |   |--- feature_0 <= 432.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 393.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 412.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 426.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  426.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [472.34]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  412.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [475.34]
# |   |   |   |   |   |   |   |   |--- feature_4 >  393.50
# |   |   |   |   |   |   |   |   |   |--- value: [472.38]
# |   |   |   |   |   |   |   |--- feature_0 >  432.50
# |   |   |   |   |   |   |   |   |--- value: [479.27]
# |   |   |   |   |   |   |--- feature_9 >  556.00
# |   |   |   |   |   |   |   |--- feature_9 <= 740.00
# |   |   |   |   |   |   |   |   |--- value: [677.33]
# |   |   |   |   |   |   |   |--- feature_9 >  740.00
# |   |   |   |   |   |   |   |   |--- value: [897.80]
# |   |   |   |   |   |--- feature_3 >  502.00
# |   |   |   |   |   |   |--- feature_8 <= 215.50
# |   |   |   |   |   |   |   |--- value: [750.29]
# |   |   |   |   |   |   |--- feature_8 >  215.50
# |   |   |   |   |   |   |   |--- value: [921.56]
# |   |   |   |   |--- feature_7 >  526.50
# |   |   |   |   |   |--- feature_4 <= 651.50
# |   |   |   |   |   |   |--- feature_8 <= 632.00
# |   |   |   |   |   |   |   |--- feature_2 <= 182.00
# |   |   |   |   |   |   |   |   |--- value: [662.67]
# |   |   |   |   |   |   |   |--- feature_2 >  182.00
# |   |   |   |   |   |   |   |   |--- value: [823.10]
# |   |   |   |   |   |   |--- feature_8 >  632.00
# |   |   |   |   |   |   |   |--- value: [914.33]
# |   |   |   |   |   |--- feature_4 >  651.50
# |   |   |   |   |   |   |--- value: [942.67]
# |   |   |   |--- feature_5 >  501.00
# |   |   |   |   |--- feature_8 <= 604.00
# |   |   |   |   |   |--- feature_5 <= 807.50
# |   |   |   |   |   |   |--- feature_4 <= 267.50
# |   |   |   |   |   |   |   |--- value: [946.75]
# |   |   |   |   |   |   |--- feature_4 >  267.50
# |   |   |   |   |   |   |   |--- value: [795.76]
# |   |   |   |   |   |--- feature_5 >  807.50
# |   |   |   |   |   |   |--- value: [926.42]
# |   |   |   |   |--- feature_8 >  604.00
# |   |   |   |   |   |--- value: [939.29]
# |   |   |--- feature_2 >  503.00
# |   |   |   |--- feature_5 <= 788.00
# |   |   |   |   |--- feature_8 <= 126.00
# |   |   |   |   |   |--- value: [789.43]
# |   |   |   |   |--- feature_8 >  126.00
# |   |   |   |   |   |--- feature_1 <= 316.50
# |   |   |   |   |   |   |--- value: [917.43]
# |   |   |   |   |   |--- feature_1 >  316.50
# |   |   |   |   |   |   |--- feature_2 <= 569.00
# |   |   |   |   |   |   |   |--- value: [664.50]
# |   |   |   |   |   |   |--- feature_2 >  569.00
# |   |   |   |   |   |   |   |--- value: [871.11]
# |   |   |   |--- feature_5 >  788.00
# |   |   |   |   |--- value: [953.31]
# |   |--- feature_1 >  504.50
# |   |   |--- feature_1 <= 909.00
# |   |   |   |--- feature_8 <= 217.00
# |   |   |   |   |--- feature_5 <= 869.50
# |   |   |   |   |   |--- feature_3 <= 742.50
# |   |   |   |   |   |   |--- feature_2 <= 722.50
# |   |   |   |   |   |   |   |--- feature_4 <= 797.00
# |   |   |   |   |   |   |   |   |--- value: [747.88]
# |   |   |   |   |   |   |   |--- feature_4 >  797.00
# |   |   |   |   |   |   |   |   |--- value: [899.33]
# |   |   |   |   |   |   |--- feature_2 >  722.50
# |   |   |   |   |   |   |   |--- value: [924.33]
# |   |   |   |   |   |--- feature_3 >  742.50
# |   |   |   |   |   |   |--- value: [904.78]
# |   |   |   |   |--- feature_5 >  869.50
# |   |   |   |   |   |--- value: [960.11]
# |   |   |   |--- feature_8 >  217.00
# |   |   |   |   |--- feature_8 <= 902.50
# |   |   |   |   |   |--- feature_4 <= 614.00
# |   |   |   |   |   |   |--- feature_0 <= 353.50
# |   |   |   |   |   |   |   |--- value: [850.94]
# |   |   |   |   |   |   |--- feature_0 >  353.50
# |   |   |   |   |   |   |   |--- value: [912.18]
# |   |   |   |   |   |--- feature_4 >  614.00
# |   |   |   |   |   |   |--- value: [929.55]
# |   |   |   |   |--- feature_8 >  902.50
# |   |   |   |   |   |--- value: [969.83]
# |   |   |--- feature_1 >  909.00
# |   |   |   |--- value: [962.68]
# |--- feature_6 >  500.50
# |   |--- feature_6 <= 900.50
# |   |   |--- feature_0 <= 788.00
# |   |   |   |--- feature_7 <= 887.00
# |   |   |   |   |--- feature_9 <= 656.50
# |   |   |   |   |   |--- feature_3 <= 814.50
# |   |   |   |   |   |   |--- feature_4 <= 801.00
# |   |   |   |   |   |   |   |--- feature_6 <= 728.00
# |   |   |   |   |   |   |   |   |--- feature_5 <= 797.00
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 454.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 660.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [707.62]
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  660.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [859.25]
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  454.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [810.43]
# |   |   |   |   |   |   |   |   |--- feature_5 >  797.00
# |   |   |   |   |   |   |   |   |   |--- value: [910.14]
# |   |   |   |   |   |   |   |--- feature_6 >  728.00
# |   |   |   |   |   |   |   |   |--- feature_5 <= 918.50
# |   |   |   |   |   |   |   |   |   |--- value: [868.98]
# |   |   |   |   |   |   |   |   |--- feature_5 >  918.50
# |   |   |   |   |   |   |   |   |   |--- value: [980.40]
# |   |   |   |   |   |   |--- feature_4 >  801.00
# |   |   |   |   |   |   |   |--- value: [929.50]
# |   |   |   |   |   |--- feature_3 >  814.50
# |   |   |   |   |   |   |--- value: [930.83]
# |   |   |   |   |--- feature_9 >  656.50
# |   |   |   |   |   |--- value: [926.19]
# |   |   |   |--- feature_7 >  887.00
# |   |   |   |   |--- value: [962.15]
# |   |   |--- feature_0 >  788.00
# |   |   |   |--- value: [953.70]
# |   |--- feature_6 >  900.50
# |   |   |--- value: [966.80]

# %%
import graphviz # for plotting decision tree graphs
from sklearn import tree

dot_data = tree.export_graphviz(model, out_file=None,
                                feature_names=names,
                                filled=True,
                                rotate=True,
                               )

graph = graphviz.Source(dot_data)

graph

# %%
from IPython.display import Image
from sklearn import tree
import matplotlib.image as mpimg
import pydotplus
import io
import matplotlib.pyplot as plt

import sys
str1 = "/usr/local/Cellar/graphviz/2.40.1_1/bin/"
sys.path.append(str1)

dot_data = io.StringIO()
tree.export_graphviz(model, out_file=dot_data, filled=True, feature_names = names )

# Draw graph
pydotplus.graph_from_dot_data(dot_data.getvalue()).write_png('dt.png')

plt.figure(figsize=(20, 20))
img = mpimg.imread('dt.png')
imgplot = plt.imshow(img)

plt.show()
